# %%
import pandas as pd
df_wo_ohe = pd.read_csv("data/ml_ready/ml_ready_13022025.csv") # without ohe
df_ohe = pd.read_csv("data/ml_ready_ohe/ml_ready_ohe_13022025.csv") # barrio one-hot-enconding

# %%
df_wo_ohe.head()
# Out:
#    antiquity  bedrooms  garages  bathrooms  rooms  total_area      price
# 0       50.0       2.0      0.0        1.0    1.0        60.0  1335750.0
# 1       60.0       2.0      0.0        1.0    1.0        58.0   350000.0
# 2       40.0       1.0      0.0        1.0    2.0        40.0   390000.0
# 3       15.0       1.0      0.0        1.0    2.0        37.0   873375.0
# 4       40.0       1.0      0.0        1.0    3.0        43.0   700000.0

# %%
df_ohe.head()
# Out:
#    antiquity  bedrooms  garages  bathrooms  rooms  total_area      price  \
# 0       50.0       2.0      0.0        1.0    1.0        60.0  1335750.0
# 1       60.0       2.0      0.0        1.0    1.0        58.0   350000.0
# 2       40.0       1.0      0.0        1.0    2.0        40.0   390000.0
# 3       15.0       1.0      0.0        1.0    2.0        37.0   873375.0
# 4       40.0       1.0      0.0        1.0    3.0        43.0   700000.0
#
#    neighborhood_Abasto  neighborhood_Agronomia  neighborhood_Agronomía  ...  \
# 0                False                   False                   False  ...
# 1                False                   False                   False  ...
# 2                False                   False                   False  ...
# 3                False                   False                   False  ...
# 4                False                   False                   False  ...
#
#    neighborhood_Villa Lugano  neighborhood_Villa Luro  \
# ...

# %%
df_wo_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15209 entries, 0 to 15208
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   antiquity   15209 non-null  float64
#  1   bedrooms    15209 non-null  float64
#  2   garages     15209 non-null  float64
#  3   bathrooms   15209 non-null  float64
#  4   rooms       15209 non-null  float64
#  5   total_area  15209 non-null  float64
#  6   price       15209 non-null  float64
# dtypes: float64(7)
# memory usage: 831.9 KB

# %% [markdown]
# # Evaluar modelos con datos sin feature 'barrio' categorizada
# categorizada -> one-hot-encoding (ohe)

# %%
# init setup
from pycaret.regression import *
clf1 = setup(data = df_wo_ohe, target = 'price')

# compare models
best_wo_ohe = compare_models()
# Out:
# <style type="text/css">
# #T_5e168_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5e168">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e168_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5e168_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e168_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e168_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5e168_row0_col1" class="data row0 col1" >4723</td>
#     </tr>
#     <tr>
#       <th id="T_5e168_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e168_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5e168_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_5e168_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Crea el modelo usando create_model
best_model_wo_ohe = create_model(best_wo_ohe)
# Out:
# <style type="text/css">
# #T_92ef5_row10_col0, #T_92ef5_row10_col1, #T_92ef5_row10_col2, #T_92ef5_row10_col3, #T_92ef5_row10_col4, #T_92ef5_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_92ef5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92ef5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_92ef5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_92ef5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_92ef5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_92ef5_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_92ef5_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
save_model(best_model_wo_ohe, 'models/model_wo_ohe_2024-12-03')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['antiquity', 'bedrooms', 'garages',
#                                               'bathrooms', 'rooms',
#                                               'total_area'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model', LGBMRegressor(n_jobs=-1, random_state=4723))]),
#  'models/model_wo_ohe_2024-12-03.pkl')

# %% [markdown]
# # Evaluar modelos con datos CON el feature 'barrio' categorizada
# categorizada -> one-hot-encoding (ohe)

# %%
# init setup
from pycaret.regression import *
clf1 = setup(data = df_ohe, target = 'price')

# compare models
best_ohe = compare_models()
# Out:
# <style type="text/css">
# #T_5db70_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5db70">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5db70_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5db70_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5db70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5db70_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5db70_row0_col1" class="data row0 col1" >6820</td>
#     </tr>
#     <tr>
#       <th id="T_5db70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5db70_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5db70_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_5db70_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Crea el modelo usando create_model
best_model_ohe = create_model(best_ohe)
# Out:
# <style type="text/css">
# #T_bcd50_row10_col0, #T_bcd50_row10_col1, #T_bcd50_row10_col2, #T_bcd50_row10_col3, #T_bcd50_row10_col4, #T_bcd50_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bcd50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcd50_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bcd50_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bcd50_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bcd50_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bcd50_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bcd50_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
save_model(best_model_ohe, 'models/model_ohe_2024-12-03')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['antiquity', 'bedrooms', 'garages',
#                                               'bathrooms', 'rooms',
#                                               'total_area'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('trained_model', LGBMRegressor(n_jobs=-1, random_state=6820))]),
#  'models/model_ohe_2024-12-03.pkl')
